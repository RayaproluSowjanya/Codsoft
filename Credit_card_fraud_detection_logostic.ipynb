# %%
#import necessary libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#reading csv file
df=pd.read_csv(r"C:\Users\User\Desktop\Codsoft\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#finding shape 
df.shape
# Out:
# (284807, 31)

# %%
#finding size
df.size
# Out:
# 8829017

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
#statistics
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
#identifying null values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#finding number of values present in class column
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#classifying normal and fraud transactions
normal_trans=df[df['Class']==0]
fraud_trans=df[df['Class']==1]

# %%
print(normal_trans.shape)
print(fraud_trans.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
normal_trans['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud_trans['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#comaring the values for both transactions
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#building a sample dataset containing similar distribution of normal and fraud transactions
normal_sample=normal_trans.sample(n=492)

# %%
df1=pd.concat([normal_sample,fraud_trans],axis=0)

# %%
df1.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 3333      2880.0  1.253551  0.224565  0.286665  0.449085 -0.008004 -0.226442
# 160382  113313.0 -2.714436  3.044536 -3.305199 -1.406683 -0.145586 -1.043348
# 70013    53672.0 -0.385109  1.137025  1.301256  0.069402  0.121756 -0.964708
# 90116    62870.0  1.104167 -0.890917 -0.548597 -0.859893  1.243432  3.902582
# 170187  120061.0  2.183153 -1.696814  0.125714 -1.382981 -2.111803 -0.405371
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 3333    0.005006 -0.061897  0.003723  ... -0.257439 -0.682704  0.099131
# 160382 -0.347337  1.959858 -0.585882  ...  0.370652  0.744213  0.061540
# 70013   0.797031 -0.132699 -0.553466  ... -0.242003 -0.607338  0.007058
# 90116  -1.122172  1.032397  1.065743  ... -0.236271 -0.762969 -0.029448
# 170187 -1.799098  0.014698 -0.539516  ... -0.128197  0.155720  0.339380
#
# ...

# %%
df1["Class"].value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
df1.groupby(["Class"]).mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94205.922764  0.032155  0.055985  0.109882 -0.039812  0.043521
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.048562  0.066369  0.029259 -0.034919  ... -0.044784  0.026509
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.001812 -0.007753 -0.009209  0.008705  0.002540  0.001924  0.011390
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       79.475772
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
x=df1.drop(['Class'],axis=1)
y=df1['Class']
print(x)
print(y)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 3333      2880.0  1.253551  0.224565  0.286665  0.449085 -0.008004 -0.226442
# 160382  113313.0 -2.714436  3.044536 -3.305199 -1.406683 -0.145586 -1.043348
# 70013    53672.0 -0.385109  1.137025  1.301256  0.069402  0.121756 -0.964708
# 90116    62870.0  1.104167 -0.890917 -0.548597 -0.859893  1.243432  3.902582
# 170187  120061.0  2.183153 -1.696814  0.125714 -1.382981 -2.111803 -0.405371
# 203052  134622.0 -0.365124  1.036996 -0.315456 -0.887105  1.214019 -0.377210
# 91339    63422.0 -0.732989  0.761198  0.663779  0.630345 -0.605200 -1.381321
# 14249    25307.0  0.953499 -0.959851  1.234708  0.917049 -1.773495 -0.386326
# 265572  161945.0 -0.606711  0.462034  1.479819 -0.778672  0.482460  1.107675
# 198655  132591.0 -0.564306 -0.216545  0.206509 -0.946398  0.938396  1.957638
# 252116  155659.0  2.079214 -0.050268 -1.423316  0.260284  0.315353 -0.698692
# ...

# %%
#training and fitting the model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
L=LogisticRegression()
L.fit(x_train,y_train)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=L.predict(x_train)

# %%
#finding accuracy score,classification report
accuracy=accuracy_score(y_train,y_pred)
print(accuracy)
classi=classification_report(y_train,y_pred)
print(classi)
# Out:
# 0.9462209302325582
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       342
#            1       0.97      0.92      0.95       346
#
#     accuracy                           0.95       688
#    macro avg       0.95      0.95      0.95       688
# weighted avg       0.95      0.95      0.95       688
